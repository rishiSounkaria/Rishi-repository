# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Matplotlib

# %%
# Line PLot

# Both the axis X and Y has to be numeric (Continious numeric) in nature.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('MagicBricks.csv')

# %%
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 4     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# ...      ...  ...       ...          ...          ...            ...
# 1209  4688.0    5       4.0  Unfurnished  Patel Nagar     West Delhi
# 1210  3901.0    4       4.0  Unfurnished  Patel Nagar     West Delhi
# 1211  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi
#
#                                                Locality  Parking  \
# 0     DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0
# ...

# %%
plt.figure(figsize=(8,4))
plt.plot(df.Area,df.Price,color='purple',marker='o',markersize=7)

# %%
# SCATTERPLOT with Matplotlib

plt.figure(figsize=(8,3))
plt.scatter(df.Area,df.Price,color='purple')
plt.xlabel('Area in Thousands')
plt.ylabel('Price in Crores')
plt.title('Delhi House Prices and Areas')
plt.grid()

# %%
# Barplot

# Barplot has 2 axis X and Y, in barplot X has to be categorical and y has to be numerical.
# Barplot can be cread on the basis of value counts.

df.Furnishing.value_counts()
# Out:
# Furnishing
# Semi-Furnished    677
# Unfurnished       361
# Furnished         176
# Name: count, dtype: int64

# %%
plt.bar(df.Furnishing.value_counts().index,df.Furnishing.value_counts())
# Out:
# <BarContainer object of 3 artists>

# %%
# We can do all those things with Baplot as well

plt.figure(figsize=(8,3))
plt.bar(df.Furnishing.value_counts().index,
        df.Furnishing.value_counts(),color=['g','y','r'],width=0.2) # If we want to pass colors according to bars
# Out:
# <BarContainer object of 3 artists>

# %%
plt.figure(figsize=(10,3))
plt.bar(df.District.value_counts().index,df.District.value_counts(),color='grey')
plt.tick_params(axis='x',rotation=50)
plt.xlabel('DISTRICTS of DELHI')
plt.ylabel('Total Homes Available in Districts')
plt.title('TOTAL DISTRICTS and HOMES')
# Out:
# Text(0.5, 1.0, 'TOTAL DISTRICTS and HOMES')

# %%
plt.figure(figsize=(10,3))
plt.barh(df.BHK.value_counts().index,df.BHK.value_counts(),color='y')
plt.xlabel('Total BHK')
plt.ylabel('Total BHK Available in DELHI')
plt.title('BHK and HOMES')
# Out:
# Text(0.5, 1.0, 'BHK and HOMES')

# %%
# Pie Plot
# Pie Plot will be created on Categorical data Like the Bar plot does.

plt.pie(x=df.Furnishing.value_counts(),labels=df.Furnishing.value_counts().index,
       autopct='%1.1f%%',shadow=True,explode=[0,0,0.11])
plt.legend(loc='lower right')

# %%
df.Furnishing.value_counts(normalize=True).round(3)
# Out:
# Furnishing
# Semi-Furnished    0.558
# Unfurnished       0.297
# Furnished         0.145
# Name: proportion, dtype: float64

# %%
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 4     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# ...      ...  ...       ...          ...          ...            ...
# 1209  4688.0    5       4.0  Unfurnished  Patel Nagar     West Delhi
# 1210  3901.0    4       4.0  Unfurnished  Patel Nagar     West Delhi
# 1211  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi
#
#                                                Locality  Parking  \
# 0     DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0
# ...

# %%
# Stack Plot in Matplotlib ___ AREA PLOT

a = [1,2,3,4,5]
b = [7,8,6,11,7]
c = [8,5,7,8,13]

# %%
plt.stackplot(df.BHK,df.Area,df.Price,colors=['r','g'])

# %%
# Boxplot with Matplotlib.

plt.boxplot(df.Price)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x226a0c11ac0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x226a0c2d040>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x226a0c11820>],
#  'medians': [<matplotlib.lines.Line2D at 0x226a0c2d580>],
#  'fliers': [<matplotlib.lines.Line2D at 0x226a0c2d820>],
#  'means': []}

# %%
# Advantage of using Matplotlib for creating Boxplots is it can run with all data in single line of code.

df.boxplot()
# Out:
# <Axes: >

# %%
plt.boxplot(df.Area)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x226a44bf730>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x226a44bf580>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x226a44bf460>],
#  'medians': [<matplotlib.lines.Line2D at 0x226a44ca1c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x226a451fa00>],
#  'means': []}

# %%
# 3-D Projection of Data in Matplotlib.

fig = plt.figure()

# %%
ax = plt.axes(projection='3d')
ax.plot(df.Area,df.Price,df.Per_Sqft)
plt.xlabel('AREA')
plt.ylabel('Price')
plt.title('ITS A 3D GRAPH')
# Out:
# Text(0.5, 0.92, 'ITS A 3D GRAPH')

# %%
ax.plot(df.Area,df.Price,df.Per_Sqft)

# %%
df.BHK.value_counts()
# Out:
# BHK
# 3     523
# 2     356
# 4     212
# 1      96
# 5      19
# 6       6
# 7       1
# 10      1
# Name: count, dtype: int64
